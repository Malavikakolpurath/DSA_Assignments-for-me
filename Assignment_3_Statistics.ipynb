# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Students_Performance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# 1. An Institution wishes to find out their student’s ability in
# mathematics, reading and writing skills. The Institution
# wants to do an exploratory study to check the following
# information.
#
# a. Find out how many males and females participated in
# the test.

# %%
ax=sns.countplot(x='gender',data=df)
plt.title('Males & Females participated in the test')

for p in ax.patches:
    ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.25))
plt.show()

# %% [markdown]
# Count of females is slightly higher than that of *males*

# %% [markdown]
# b. What do you think about the students' parental level of
# education?

# %%
df['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
sns.countplot(y='parental level of education',data=df)
# Out:
# <Axes: xlabel='count', ylabel='parental level of education'>

# %% [markdown]
# i) Most of the parents have 'some college' education or 'associate college' education (22-23%).
#
# ii) Next comes the 'high school' or 'some high school' level of education (18-20%).
#
# iii) 12% has bachlore's degree education.
#
# iv) Only 6% of parents have master's degree.

# %% [markdown]
# c. Who scores the most on average for math, reading and
# writing based on
#
# i. Gender
#
# ii. Test preparation course

# %% [markdown]
# Average Math score with respect to gender and Test preperation

# %%
df.groupby('gender')['math score'].mean()
# Out:
# gender
# female    63.376448
# male      68.821577
# Name: math score, dtype: float64

# %%
df.groupby('test preparation course')['math score'].mean()
# Out:
# test preparation course
# completed    69.96648
# none         63.78972
# Name: math score, dtype: float64

# %% [markdown]
# Average math score of male students are higher compared to females
#
# Average math score for students who have completed the preparation course is higher compared to those who haven't done any preparation

# %% [markdown]
# Average Reading score with respect to gender and Test preperation:

# %%
df.groupby('gender')['reading score'].mean()
# Out:
# gender
# female    72.590734
# male      65.545643
# Name: reading score, dtype: float64

# %%
df.groupby('test preparation course')['reading score'].mean()
# Out:
# test preparation course
# completed    74.175978
# none         66.417445
# Name: reading score, dtype: float64

# %% [markdown]
# Average reading score of female students are higher compared to males
#
# Average reading score for students who have completed the preparation course is higher compared to those who haven't done any preparation

# %% [markdown]
# Average Writing score with respect to gender and Test preperation:

# %%
df.groupby('gender')['writing score'].mean()
# Out:
# gender
# female    72.467181
# male      63.446058
# Name: writing score, dtype: float64

# %%
df.groupby('test preparation course')['writing score'].mean()
# Out:
# test preparation course
# completed    74.684358
# none         64.457944
# Name: writing score, dtype: float64

# %% [markdown]
# Average writing score af female students are higher compared to males

# %% [markdown]
# Average writing score for students who have completed the preparation course is higher compared to those who havent done any preparation

# %% [markdown]
# d. What do you think about the scoring variation for
# math, reading and writing based on
#
# i. Gender
#
# ii. Test preparation course

# %% [markdown]
# Scoring variation for math, reading & writing compared to gender:

# %%
plt.figure(figsize=(12,10))

plt.subplot(3,3,1)
sns.boxplot(x='gender',y='math score',data=df )

plt.subplot(3,3,2)
sns.boxplot(x='gender',y='reading score',data=df )

plt.subplot(3,3,3)
sns.boxplot(x='gender',y='writing score',data=df)

plt.tight_layout()

# %% [markdown]
# Variance in math, writing & reading score is higher with students without test prepartion course than compared with students who have taken the course

# %% [markdown]
# e. The management needs your help to give bonus points
# to the top 25% of students based on their math score,
# so how will you help the management to achieve this.

# %%
df['math score'].describe()
# Out:
# count    1000.000000
# mean       66.001000
# std        15.569567
# min         0.000000
# 25%        57.000000
# 50%        66.000000
# 75%        77.000000
# max       100.000000
# Name: math score, dtype: float64

# %% [markdown]
# Students who have scored 77% and above in Maths test can be given the bonus points

# %%
dfB=df[df['math score']>=77]
dfB.describe()
# Out:
#        math score  reading score  writing score
# count  255.000000     255.000000     255.000000
# mean    84.894118      84.070588      83.117647
# std      6.308394       9.065972       9.727886
# min     77.000000      60.000000      61.000000
# 25%     80.000000      78.000000      76.000000
# 50%     84.000000      84.000000      83.000000
# 75%     89.000000      90.000000      91.000000
# max    100.000000     100.000000     100.000000

# %% [markdown]
# List of students who deserve the bonus points:

# %%
dfB.head(255)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 414  female        group A                 high school  free/reduced
# 415  female        group B             master's degree  free/reduced
# 416  female        group B           bachelor's degree  free/reduced
# 417  female        group B             master's degree      standard
# 418  female        group B                 high school      standard
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# Case Study on Testing of Hypothesis:

# %% [markdown]
# 2. A company started to invest in digital marketing as a new
# way of their product promotions. For that they collected
# data and decided to carry out a study on it.

# %% [markdown]
# a. The company wishes to clarify whether there is any
# increase in sales after stepping into digital marketing.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
df1=pd.read_csv("Sales_add.csv")
df1
# Out:
#        Month      Region      Manager  Sales_before_digital_add(in $)  \
# 0    Month-1  Region - A  Manager - A                          132921
# 1    Month-2  Region - A  Manager - C                          149559
# 2    Month-3  Region - B  Manager - A                          146278
# 3    Month-4  Region - B  Manager - B                          152167
# 4    Month-5  Region - C  Manager - B                          159525
# 5    Month-6  Region - A  Manager - B                          137163
# 6    Month-7  Region - C  Manager - C                          130625
# 7    Month-8  Region - A  Manager - A                          131140
# 8    Month-9  Region - B  Manager - C                          171259
# 9   Month-10  Region - C  Manager - B                          141956
# 10  Month-11  Region - B  Manager - C                          159339
# 11  Month-12  Region - A  Manager - A                          178939
# ...

# %% [markdown]
# Case Study on Testing of Hypothesis
#
# 2. A company started to invest in digital marketing as a new
# way of their product promotions. For that they collected
# data and decided to carry out a study on it.
#
# a. The company wishes to clarify whether there is any
# increase in sales after stepping into digital marketing.

# %%
df1.isna().sum()
# Out:
# Month                             0
# Region                            0
# Manager                           0
# Sales_before_digital_add(in $)    0
# Sales_After_digital_add(in $)     0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 5 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Month                           22 non-null     object
#  1   Region                          22 non-null     object
#  2   Manager                         22 non-null     object
#  3   Sales_before_digital_add(in $)  22 non-null     int64
#  4   Sales_After_digital_add(in $)   22 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 1008.0+ bytes

# %% [markdown]
# Testing for increase in sales( Using Paired t-test)
#
# Here the company wishes to clarify whether there is any increase in sales after stepping into digital marketing
#
#
# H0:There is no diffrence in sales after digital marketing
#
#
# H1:There is increase in sales after digital marketing

# %%
df1.describe()
# Out:
#        Sales_before_digital_add(in $)  Sales_After_digital_add(in $)
# count                       22.000000                      22.000000
# mean                    149239.954545                  231123.727273
# std                      14844.042921                   25556.777061
# min                     130263.000000                  187305.000000
# 25%                     138087.750000                  214960.750000
# 50%                     147444.000000                  229986.500000
# 75%                     157627.500000                  250909.000000
# max                     178939.000000                  276279.000000

# %% [markdown]
# For calculation of t-statistic

# %%
from scipy import stats
stats.ttest_rel(df1['Sales_After_digital_add(in $)'], df1['Sales_before_digital_add(in $)'],alternative='greater')
# Out:
# TtestResult(statistic=12.09070525287017, pvalue=3.168333502287889e-11, df=21)

# %% [markdown]
# ie; calulated t statistic value is 12.091 and p value is 0.
#
#
# Since p value < 0.05, we reject H0.
#  ie; We can conclude that there is an increase in the sales after the digital marketing

# %% [markdown]
# b. The company needs to check whether there is any
# dependency between the features “Region” and
# “Manager”.

# %% [markdown]
# Testing for dependency in features (Chi-sqaure test)
# Here the company needs to check whether there is any dependancy between "Region" and "Manager"
#
#
# H0: There is no dependancy between Region & Manager
#
#
# H1: There is dependancy between Region & Manager
#
#
# For calculation of Chi-square statistic

# %%
df1['Region'].value_counts()
# Out:
# Region - A    10
# Region - B     7
# Region - C     5
# Name: Region, dtype: int64

# %%
df1['Manager'].value_counts()
# Out:
# Manager - A    9
# Manager - B    7
# Manager - C    6
# Name: Manager, dtype: int64

# %%
crosstab=pd.crosstab(df1.Region,df1.Manager) # observed frequencies
crosstab
# Out:
# Manager     Manager - A  Manager - B  Manager - C
# Region
# Region - A            4            3            3
# Region - B            4            1            2
# Region - C            1            3            1

# %%
import scipy.stats as stats
stats.chi2_contingency(crosstab)
# Out:
# Chi2ContingencyResult(statistic=3.050566893424036, pvalue=0.5493991051158094, dof=4, expected_freq=array([[4.09090909, 3.18181818, 2.72727273],
#        [2.86363636, 2.22727273, 1.90909091],
#        [2.04545455, 1.59090909, 1.36363636]]))

# %% [markdown]
# Cal_chi = 3.0506, p_value = 0.5494, degrees of freedom = 4, array gives the expected frequencies
#
#
# Here p-value > 0.05 which implies we accept that "There is no depandancy between the 'Region' & 'Manager'"
#
#
# OR

# %%
import scipy
Table_chi=scipy.stats.chi2.ppf(1-.05, df=4) # Finding Table value of chi-square
Table_chi
# Out:
# 9.487729036781154

# %% [markdown]
# Since Cal_chi < Table_chi, we accept H0. ie;There is no dependancy between the 'Region' and 'Manager'
